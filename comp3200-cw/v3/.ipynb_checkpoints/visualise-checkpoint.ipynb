# %%
import numpy as np
from matplotlib import pyplot as plt
from os import listdir
import json
import pandas as pd

# %%
def get_y_val(x, xs, ys):
    for i in range(xs.shape[0]):
        if xs[i] > x:
            # This is upper bound, previous is lower bound
            if i == 0:
                end, start = xs[i], 0
                l = (x-start)/(end-start)
                return ys[i]#(l)*ys[i]
            end, start = xs[i], xs[i-1]
            l = (x-start)/(end-start)
            return (l)*ys[i] + (1-l)*ys[i-1]
    return ys[len(ys)-1]

def get_average_plot(data):
    end_time = 0
    for es in data["epochs"]:
        end_time = max(end_time, np.max(es))
    xs = np.array(range(0, int(end_time)))
    yss = np.array([[get_y_val(x, data["epochs"][di], data["accuracies"][di]) for x in xs] for di in range(len(data["epochs"]))])
    ys_avg = np.median(yss, axis=0)#np.mean(yss, axis=0)
    ys_q75, ys_q25 = np.percentile(yss, [75 ,25], axis=0)
    #ys_std = np.std(yss, axis=0)
    return xs, ys_avg, ys_q75, ys_q25

def average_plot(data, color=(0.02745098, 0.50588235, 0.87058824), plot_std=True, label=None):
    xs, ys_avg, ys_q75, ys_q25 = get_average_plot(data)
    if plot_std:
        plt.fill_between(xs, ys_q25, ys_q75, color=(color[0], color[1], color[2], 0.25))
    plt.plot(xs, ys_avg, color=color, label=label)

# %%
def setup_accuracy_graph(title, zoom=None, legend=True):
    plt.xticks([x for x in range(0, 21, 1)])
    if zoom is not None:
        plt.ylim(zoom[0], zoom[1])
        plt.yticks([x for x in range(zoom[0], zoom[1]+1, 1)])
    else:
        plt.ylim(0, 100)
        plt.yticks([x for x in range(0, 110, 10)])
    plt.xlim(0, 20)
    plt.xlabel("Training Step")
    plt.ylabel("Median Accuracy (%)")
    plt.grid()
    if legend:
        plt.legend()
    #plt.title(title)
    print(r"\center{\textbf{"+title+r"}} \\")

# %%
def colors(a, b, n):
    def lerp(a,b,x):
        return (1-x)*a + x*b
    x = 1/(n-1)
    cols = []
    for ni in range(n):
        xi = ni*x
        cols.append((lerp(a[0], b[0], xi), lerp(a[1], b[1], xi), lerp(a[2], b[2], xi)))
    return cols

# %%
def read_database(path="./data"):
    db = []
    for filename in listdir(path):
        with open(path+"/"+filename, "r") as f:
            js = json.loads(f.read())
            exmajor, exminor = int(filename.split(".")[0][len("test"):]), int(filename.split(".")[1])
            js["exmajor"], js["exminor"] = exmajor, exminor
            db.append(js)
    return db

def find_data(db, condition=lambda x: True):
    epochs = []
    data = []
    msds = []
    for d in db:
        if condition(d):
            epochs.extend([np.array(x) for x in d['epochs']])
            data.extend([np.array(x) for x in d['accuracies']])
            msds.extend([np.array(x) for x in d['msds']])
    if len(data) == 0:
        print("Cant find data")
    return {"epochs":np.array(epochs), "accuracies":np.array(data), "msds":np.array(msds)}

# %%
db = read_database()

# %%
# aeg_dense_1000
average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == 0), label="FedAvg", color=(0,0,0))
average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == 3), label="SwarmAvg", color=(1,0,0))
setup_accuracy_graph("Accuracy by Training Step for 1000 Samples")
plt.show()
# Out:
# \center{\textbf{Accuracy by Training Step for 1000 Samples}} \\

# %%
# aeg_dense_100
average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == 1), label="FedAvg", color=(0,0,0))
average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == 4), label="SwarmAvg", color=(1,0,0))
setup_accuracy_graph("Accuracy by Training Step for 100 Samples")
plt.show()
# Out:
# \center{\textbf{Accuracy by Training Step for 100 Samples}} \\

# %%
# aeg_dense_25
average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == 2), label="FedAvg", color=(0,0,0))
average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == 5), label="SwarmAvg", color=(1,0,0))
setup_accuracy_graph("Accuracy by Training Step for 25 Samples")
plt.show()
# Out:
# \center{\textbf{Accuracy by Training Step for 25 Samples}} \\

# %%
# aeg_sparse_1000
cols = colors((0,1,0), (0,0,1),5)
for zoom in [None, (80,90)]:
    for x in [(3, 1.0, cols[0]),(6, 0.75, cols[1]),(9, 0.5, cols[2]),(12, 0.25, cols[3]),(15, 0.0, cols[4])]:
        average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == x[0]), label="SwarmAvg density=%s"%x[1], color=x[2], plot_std=False)
    setup_accuracy_graph("Accuracy by Training Step for 1000 Samples for Different Densities", zoom=zoom)
    plt.show()
# Out:
# \center{\textbf{Accuracy by Training Step for 1000 Samples for Different Densities}} \\
# \center{\textbf{Accuracy by Training Step for 1000 Samples for Different Densities}} \\

# %%
# aeg_sparse_100
cols = colors((0,1,0), (0,0,1),5)
for zoom in [None, (70,80)]:
    for x in [(3, 1.0, cols[0]),(6, 0.75, cols[1]),(9, 0.5, cols[2]),(12, 0.25, cols[3]),(15, 0.0, cols[4])]:
        average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == x[0]+1), label="SwarmAvg density=%s"%x[1], color=x[2], plot_std=False)
    setup_accuracy_graph("Accuracy by Training Step for 100 Samples for Different Densities", zoom=zoom)
    plt.show()
# Out:
# \center{\textbf{Accuracy by Training Step for 100 Samples for Different Densities}} \\
# \center{\textbf{Accuracy by Training Step for 100 Samples for Different Densities}} \\

# %%
# aeg_sparse_25
cols = colors((0,1,0), (0,0,1),5)
for zoom in [None, (70,80)]:
    for x in [(3, 1.0, cols[0]),(6, 0.75, cols[1]),(9, 0.5, cols[2]),(12, 0.25, cols[3]),(15, 0.0, cols[4])]:
        average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == x[0]+2), label="SwarmAvg density=%s"%x[1], color=x[2], plot_std=False)
    setup_accuracy_graph("Accuracy by Training Step for 25 Samples for Different Densities", zoom=zoom)
    plt.show()
# Out:
# Cant find data
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [14], line 5
#       3 for zoom in [False, True]:
#       4     for x in [(3, 1.0, cols[0]),(6, 0.75, cols[1]),(9, 0.5, cols[2]),(12, 0.25, cols[3]),(15, 0.0, cols[4])]:
# ----> 5         average_plot(find_data(db, condition=lambda ex: ex["exmajor"] == x[0]+2), label="SwarmAvg density=%s"%x[1], color=x[2], plot_std=False)
#       6     setup_accuracy_graph("Accuracy by Training Step for 25 Samples for Different Densities", zoom=zoom)
#       7     plt.show()
#
# Cell In [2], line 26, in average_plot(data, color, plot_std, label)
#      25 def average_plot(data, color=(0.02745098, 0.50588235, 0.87058824), plot_std=True, label=None):
# ---> 26     xs, ys_avg, ys_q75, ys_q25 = get_average_plot(data)
#      27     if plot_std:
#      28         plt.fill_between(xs, ys_q25, ys_q75, color=(color[0], color[1], color[2], 0.25))
#
# Cell In [2], line 21, in get_average_plot(data)
#      19 yss = np.array([[get_y_val(x, data["epochs"][di], data["accuracies"][di]) for x in xs] for di in range(len(data["epochs"]))])
#      20 ys_avg = np.median(yss, axis=0)#np.mean(yss, axis=0)
# ---> 21 ys_q75, ys_q25 = np.percentile(yss, [75 ,25], axis=0)
#      22 #ys_std = np.std(yss, axis=0)
#      23 return xs, ys_avg, ys_q75, ys_q25
#
# File <__array_function__ internals>:180, in percentile(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:4166, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4164 if not _quantile_is_valid(q):
#    4165     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4166 return _quantile_unchecked(
#    4167     a, q, axis, out, overwrite_input, method, keepdims)
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:4424, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4416 def _quantile_unchecked(a,
#    4417                         q,
#    4418                         axis=None,
#    (...)
#    4421                         method="linear",
#    4422                         keepdims=False):
#    4423     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4424     r, k = _ureduce(a,
#    4425                     func=_quantile_ureduce_func,
#    4426                     q=q,
#    4427                     axis=axis,
#    4428                     out=out,
#    4429                     overwrite_input=overwrite_input,
#    4430                     method=method)
#    4431     if keepdims:
#    4432         return r.reshape(q.shape + k)
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:4593, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4591     else:
#    4592         arr = a.copy()
# -> 4593 result = _quantile(arr,
#    4594                    quantiles=q,
#    4595                    axis=axis,
#    4596                    method=method,
#    4597                    out=out)
#    4598 return result
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:4699, in _quantile(arr, quantiles, axis, method, out)
#    4691 arr.partition(
#    4692     np.unique(np.concatenate(([0, -1],
#    4693                               previous_indexes.ravel(),
#    4694                               next_indexes.ravel(),
#    4695                               ))),
#    4696     axis=DATA_AXIS)
#    4697 if np.issubdtype(arr.dtype, np.inexact):
#    4698     slices_having_nans = np.isnan(
# -> 4699         take(arr, indices=-1, axis=DATA_AXIS)
#    4700     )
#    4701 else:
#    4702     slices_having_nans = None
#
# File <__array_function__ internals>:180, in take(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:190, in take(a, indices, axis, out, mode)
#      93 @array_function_dispatch(_take_dispatcher)
#      94 def take(a, indices, axis=None, out=None, mode='raise'):
#      95     """
#      96     Take elements from an array along an axis.
#      97
#    (...)
#     188            [5, 7]])
#     189     """
# --> 190     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#
# File /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# IndexError: cannot do a non-empty take from an empty axes.
