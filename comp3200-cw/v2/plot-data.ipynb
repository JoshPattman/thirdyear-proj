# %%
from matplotlib import pyplot as plt

# %%
data = [([3.362242, 19.347241, 43.586317, 67.850867, 94.95576299999999, 119.100135], [11.08, 89.99, 94.93, 97.48, 98.4, 98.7]), ([6.003852, 24.818612, 48.6239, 72.354694, 96.195522, 119.939009], [11.09, 88.1, 96.15, 97.77, 97.98, 98.54]), ([9.792577, 30.761117, 54.62618, 78.523962, 102.36020099999999, 124.580422], [11.09, 90.69, 96.11, 97.53, 98.38, 98.69]), ([14.383907, 35.769789, 59.688616, 83.60023899999999, 107.40015400000001, 128.35083], [11.09, 92.14, 97.18, 97.67, 98.2, 98.68]), ([18.903133, 43.634301, 67.788667, 94.042783, 119.068834, 132.111497], [11.09, 92.44, 97.09, 97.88, 98.45, 98.76])]

# %%
for d in data:
    plt.plot(d[0], d[1], "g")
plt.grid()
plt.show()

# %%
ball
plt.plot()
