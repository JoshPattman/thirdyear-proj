# %%
from matplotlib import pyplot as plt

# %%
data = [([0, 3.293702, 9.119404, 19.457548, 32.09441, 47.679231], [5.85, 71.84, 69.97, 77.02, 81.62, 82.6]), ([0, 6.088681, 16.374478, 29.122651, 44.494301, 56.694473], [5.85, 75.25, 77.26, 79.74, 82.9, 85.94]), ([0, 10.893796, 23.586193, 38.882006, 51.060545, 60.271264], [52.49, 79.29, 80.09, 82.89, 86.2, 87.91]), ([0, 23.916426, 37.089012, 46.469788, 52.700038, 58.844432], [63.48, 84.02, 87.55, 88.01, 88.39, 88.25]), ([0, 15.854917, 27.991224, 37.152807, 43.276948, 46.516449], [73.31, 86.66, 88.98, 89.41, 86.07, 89.36])]

# %%
for d in data:
    plt.plot(d[0], d[1], "g")
plt.grid()
baplt.show()

# %%
ball
plt.plot()
