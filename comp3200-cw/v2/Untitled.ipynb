# %%
from matplotlib import pyplot as plt

# %%
data = [([0, 15.795927, 39.947631, 63.983063, 87.900336, 111.810677], [9.57, 92.11, 95.53, 98.11, 98.34, 98.62]), ([0, 18.748319, 42.551492, 66.535639, 90.407573, 113.803644], [9.57, 90.58, 97.31, 98.01, 98.48, 98.62]), ([0, 20.928908, 44.690799, 68.621107, 92.530131, 114.665235], [9.57, 95.45, 97.76, 98.44, 98.5, 98.72]), ([0, 21.422985, 45.206822, 69.184532, 93.147422, 113.898614], [9.57, 93.47, 97.73, 98.36, 98.62, 98.72]), ([0, 24.665786, 48.811767, 72.891753, 96.745179, 112.823569], [9.57, 95.83, 98.06, 98.49, 98.48, 98.68])]

# %%
for d in data:
    plt.plot(d[0], d[1])
plt.grid()
plt.show()
